# %%
from preprocessing import *
import librosa
from utile import *

# %%
filename1 = "./data/train/audio/no/012c8314_nohash_0.wav"
filename2 = "./data/train/audio/no/0132a06d_nohash_3.wav"
filename3 = "./data/train/audio/yes/004ae714_nohash_0.wav"
filename4 = "./data/train/audio/yes/012c8314_nohash_0.wav"

# %%
y1, sr1 = librosa.load(filename1)
y2, sr2 = librosa.load(filename2)
y3, sr3 = librosa.load(filename3)
y4, sr4 = librosa.load(filename4)

# %%
plot_Mel_spectrogram(y1, sr1)

# %%
plot_Mel_spectrogram(y2, sr2)

# %%
plot_Mel_spectrogram(y3, sr3)

# %%
plot_Mel_spectrogram(y4, sr4)

# %%
d = librosa.core.get_duration(filename=filename1)
y, sr = librosa.load(filename1)

# %%
S = librosa.feature.melspectrogram(y, sr=sr, n_mels=128, hop_length=len(y)/10)
log_S = librosa.power_to_db(S, ref=np.max)

# %%
log_S.shape
# Out:
# (128, 11)

# %%
sr
# Out:
# 22050

# %%
len(y2)
# Out:
# 4096

# %%
len(y)
# Out:
# 10240

# %%
import numpy as np

# %%
np.linalg.norm(output3-output2)
# Out:
# 511.0540752935787
