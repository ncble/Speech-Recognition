# %%
import numpy as np
import librosa
import matplotlib.pyplot as plt
import librosa.display
import os
from scipy import signal
from scipy.fftpack import fft
import IPython.display as ipd
from utile import plot_wave, cut, mfcc

# %%
path = os.path.join("data", "train")

# %%
validating_set = open(os.path.join(path, "validation_list.txt"))
validating_list = validating_set.readlines()
validating_set.close()
print("Nombre de fichiers pour la validation : " + str(len(validating_list)))
# Out:
# Nombre de fichiers pour la validation : 6798

# %%
test_set = open(os.path.join(path, "testing_list.txt"))
test_list = test_set.readlines()
test_set.close()
print("Nombre de fichiers pour le test : " + str(len(test_list)))
# Out:
# Nombre de fichiers pour le test : 6835

# %%
filename = os.path.join(path, "audio", validating_list[1000][:-1])

# %%
y, sr = librosa.load(filename)
plot_wave(y,sr)

# %%
ipd.Audio(filename)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
y.shape
# Out:
# (22050,)

# %%
y = cut(y)
# Out:
# [ 7680 13312]

# %%
log_S = mfcc(y, sr, plot=True)

# %%
log_S.shape
# Out:
# (128, 44)

# %%
y
# Out:
# array([0., 0., 0., ..., 0., 0., 0.], dtype=float32)
