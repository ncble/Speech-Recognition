# %%
# %matplotlib nbagg
import numpy as np
import librosa
import matplotlib.pyplot as plt
import librosa.display
import IPython.display as ipd
from scipy.io import wavfile
from scipy.fftpack import fft
from utile import *

# %%
for file_name in generator(folder = "yes", stop_after=10):
    y, sr = load_audio_file(file_name)
#     y, sr = resize_audio(y, sr)
    print(file_name, sr)
    plot_Mel_spectrogram(y, sr)
# Out:
# ('./data/train/audio/yes/e7334395_nohash_2.wav', 16000)
# ('./data/train/audio/yes/b87bdb22_nohash_4.wav', 16000)
# ('./data/train/audio/yes/2dce72b3_nohash_1.wav', 16000)
# ('./data/train/audio/yes/dc75148d_nohash_0.wav', 16000)
# ('./data/train/audio/yes/9b3ea809_nohash_0.wav', 16000)
# ('./data/train/audio/yes/0c2ca723_nohash_0.wav', 16000)
# ('./data/train/audio/yes/dea820ce_nohash_3.wav', 16000)
# ('./data/train/audio/yes/179a61b7_nohash_2.wav', 16000)
# ('./data/train/audio/yes/df1d5024_nohash_1.wav', 16000)
# ('./data/train/audio/yes/190821dc_nohash_2.wav', 16000)

# %% [markdown]
# Attention ! False positive label !  Need anomaly detection !
# ===================

# %%
ipd.Audio("./data/train/audio/yes/190821dc_nohash_2.wav")  # no sound
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ipd.Audio("./data/train/audio/yes/179a61b7_nohash_2.wav")  # noisy
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ipd.Audio("./data/train/audio/seven/b1114e4f_nohash_0.wav")  # baby
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ipd.Audio("./data/train/audio/yes/e4b02540_nohash_0.wav")
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
y, sr = load_audio_file("./data/train/audio/yes/179a61b7_nohash_2.wav")
new_y = signal.resample(y, int(8000./sr * len(y)))
ipd.Audio(new_y, rate = 8000)
print(len(y))
print(len(new_y))
# Out:
# 16000
# 8000

# %%
for no_file in generator(folder = "no", stop_after=10):
    y, sr = load_audio_file(no_file)
    print(no_file)
    plot_Mel_spectrogram(y, sr)
# Out:
# ./data/train/audio/no/135c6841_nohash_3.wav
# ./data/train/audio/no/538e1856_nohash_0.wav
# ./data/train/audio/no/0d97f020_nohash_0.wav
# ./data/train/audio/no/b87bdb22_nohash_4.wav
# ./data/train/audio/no/0bde966a_nohash_1.wav
# ./data/train/audio/no/dc75148d_nohash_0.wav
# ./data/train/audio/no/9b3ea809_nohash_0.wav
# ./data/train/audio/no/0c2ca723_nohash_0.wav
# ./data/train/audio/no/dea820ce_nohash_3.wav
# ./data/train/audio/no/179a61b7_nohash_2.wav

# %%
for file_path in generator(folder = "seven", stop_after=10):
    y, sr = load_audio_file(file_path)
    print(file_path)
    plot_Mel_spectrogram(y, sr)
# Out:
# ./data/train/audio/seven/538e1856_nohash_0.wav
# ./data/train/audio/seven/b87bdb22_nohash_4.wav
# ./data/train/audio/seven/9e075bf1_nohash_3.wav
# ./data/train/audio/seven/2dce72b3_nohash_1.wav
# ./data/train/audio/seven/0bde966a_nohash_1.wav
# ./data/train/audio/seven/dc75148d_nohash_0.wav
# ./data/train/audio/seven/9b3ea809_nohash_0.wav
# ./data/train/audio/seven/0c2ca723_nohash_0.wav
# ./data/train/audio/seven/dea820ce_nohash_3.wav
# ./data/train/audio/seven/179a61b7_nohash_2.wav
